# %%
from visualise import *

# %%
PATH_CSV = "../Images/StyleTransferImages/metrics_depth2.csv"

# %%
Stat_compare_folders(PATH_CSV)

# %%
Gini_compare_folders(PATH_CSV)

# %%
LBP_hist_per_folder(PATH_CSV)

# %%
Haralick_compare_folders(PATH_CSV)
# Out:
# /home/durrmeyer/.local/lib/python3.6/site-packages/seaborn/axisgrid.py:64: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self.fig.tight_layout(*args, **kwargs)
# /home/durrmeyer/.local/lib/python3.6/site-packages/seaborn/axisgrid.py:64: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self.fig.tight_layout(*args, **kwargs)
# /home/durrmeyer/.local/lib/python3.6/site-packages/seaborn/axisgrid.py:64: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self.fig.tight_layout(*args, **kwargs)
# /home/durrmeyer/.local/lib/python3.6/site-packages/seaborn/axisgrid.py:64: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
# ...

# %%
Gini_compare_folders(PATH_CSV)

# %%
transfer_effect_slope(PATH_CSV)
