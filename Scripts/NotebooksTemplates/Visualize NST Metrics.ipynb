# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # VISUALIZE NST METRICS

# %%
path_img_list = "../../Results/NST_metrics/image_list.csv"
img_list = pd.read_csv(path_img_list, index_col=0)
img_list.head(3)
# Out:
#                                                    Image_path  \
# image_list
# 0           /home/durrmeyer/Images/StyleTransferImages/HAB...
# 1           /home/durrmeyer/Images/StyleTransferImages/HAB...
# 2           /home/durrmeyer/Images/StyleTransferImages/HAB...
#
#                                                      filename     type  \
# image_list
# 0           PLANTS_cropped_3000x1000_middle_tt_resized_div...  habitat
# 1           DETRITUS_cropped_3000x1000_middle_tt_resized_d...  habitat
# 2           SAND_Eolmstedi_cropped_3000x1000_middle_tt_res...  habitat
#
#                     folder   habitat color_control tv_loss layers  sex  \
# image_list
# 0           HABITAT_images    PLANTS           NaN     NaN    NaN  NaN
# 1           HABITAT_images  DETRITUS           NaN     NaN    NaN  NaN
# 2           HABITAT_images      SAND           NaN     NaN    NaN  NaN
#
#             fish_n species  img_width  img_height image_extension
# image_list
# 0              NaN     NaN       3000        1000            .jpg
# 1              NaN     NaN       3000        1000            .jpg
# 2              NaN     NaN       3000        1000            .jpg

# %% [markdown]
# # LBP

# %%
path_lbp = "../../Results/NST_metrics/best_lbp.csv"
lbp_data = pd.read_csv(path_lbp, index_col=0)
lbp_data = lbp_data.merge(img_list, on="Image_path")
lbp_data.columns
# Out:
# Index(['normalization', 'standardization', 'image_type', 'channel_image',
#        'image_resize_x', 'image_resize_y', 'Image_path', 'points_LBP',
#        'radius_LBP', 'rank_lbp_value', 'value_LBP', 'count_LBP_value',
#        'filename', 'type', 'folder', 'habitat', 'color_control', 'tv_loss',
#        'layers', 'sex', 'fish_n', 'species', 'img_width', 'img_height',
#        'image_extension'],
#       dtype='object')

# %%
for params, grp in lbp_data.groupby(["radius_LBP", "points_LBP"]):
    print(params)
    sns.catplot(data=grp, x="value_LBP", y="count_LBP_value", hue="folder")
    plt.show()
# Out:
# (2.0, 8.0)
# (4.0, 16.0)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/cefe/lib/python3.8/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#     942         try:
# --> 943             self._set_with_engine(key, value)
#     944         except (KeyError, ValueError):
#
# ~/anaconda3/envs/cefe/lib/python3.8/site-packages/pandas/core/series.py in _set_with_engine(self, key, value)
#     975         # fails with AttributeError for IntervalIndex
# --> 976         loc = self.index._engine.get_loc(key)
#     977         validate_numeric_casting(self.dtype, value)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '1777     False
# 2577     False
# 2972     False
# 3188     False
# 3392     False
#          ...
# 35955    False
# 36580    False
# 36750    False
# 36949    False
# 37388    False
# Name: folder, Length: 87, dtype: bool' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-645e8ce23059> in <module>
#       1 for params, grp in lbp_data.groupby(["radius_LBP", "points_LBP"]):
#       2     print(params)
# ----> 3     sns.catplot(data=grp, x="value_LBP", y="count_LBP_value", hue="folder")
#       4     plt.show()
#
# ~/anaconda3/envs/cefe/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/envs/cefe/lib/python3.8/site-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3842
#    3843     # Draw the plot onto the facets
# -> 3844     g.map_dataframe(plot_func, x=x, y=y, hue=hue, **plot_kws)
#    3845
#    3846     if p.orient == "h":
#
# ~/anaconda3/envs/cefe/lib/python3.8/site-packages/seaborn/axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     748
#     749             # Draw the plot
# --> 750             self._facet_plot(func, ax, args, kwargs)
#     751
#     752         # Finalize the annotations and layout
#
# ~/anaconda3/envs/cefe/lib/python3.8/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     773             plot_args = []
#     774             plot_kwargs["ax"] = ax
# --> 775         func(*plot_args, **plot_kwargs)
#     776
#     777         # Sort out the supporting information
#
# ~/anaconda3/envs/cefe/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/envs/cefe/lib/python3.8/site-packages/seaborn/categorical.py in stripplot(x, y, hue, data, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2817                        linewidth=linewidth))
#    2818
# -> 2819     plotter.plot(ax, kwargs)
#    2820     return ax
#    2821
#
# ~/anaconda3/envs/cefe/lib/python3.8/site-packages/seaborn/categorical.py in plot(self, ax, kws)
#    1158     def plot(self, ax, kws):
#    1159         """Make the plot."""
# -> 1160         self.draw_stripplot(ax, kws)
#    1161         self.add_legend_data(ax)
#    1162         self.annotate_axes(ax)
#
# ~/anaconda3/envs/cefe/lib/python3.8/site-packages/seaborn/categorical.py in draw_stripplot(self, ax, kws)
#    1127
#    1128                 strip_data = group_data[hue_mask]
# -> 1129                 point_colors = np.asarray(self.point_colors[i][hue_mask])
#    1130
#    1131                 # Plot the points in centered positions
#
# ~/anaconda3/envs/cefe/lib/python3.8/site-packages/seaborn/categorical.py in point_colors(self)
#    1076                     # hue_color = self.colors[j]
#    1077                     if group_data.size:
# -> 1078                         group_colors[self.plot_hues[i] == level] = j
#    1079
#    1080             point_colors.append(group_colors)
#
# ~/anaconda3/envs/cefe/lib/python3.8/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#     961                 key = np.asarray(key, dtype=bool)
#     962                 try:
# --> 963                     self._where(~key, value, inplace=True)
#     964                 except InvalidIndexError:
#     965                     self.iloc[key] = value
#
# ~/anaconda3/envs/cefe/lib/python3.8/site-packages/pandas/core/generic.py in _where(self, cond, other, inplace, axis, level, errors, try_cast)
#    9041             cond = cond.astype(bool)
#    9042
# -> 9043         cond = -cond if inplace else cond
#    9044
#    9045         # try to align with other
#
# ~/anaconda3/envs/cefe/lib/python3.8/site-packages/pandas/core/generic.py in __neg__(self)
#    1407         else:
#    1408             raise TypeError(f"Unary negative expects numeric dtype, not {values.dtype}")
# -> 1409         return self.__array_wrap__(arr)
#    1410
#    1411     @final
#
# ~/anaconda3/envs/cefe/lib/python3.8/site-packages/pandas/core/generic.py in __array_wrap__(self, result, context)
#    1926             return result
#    1927         d = self._construct_axes_dict(self._AXIS_ORDERS, copy=False)
# -> 1928         return self._constructor(result, **d).__finalize__(
#    1929             self, method="__array_wrap__"
#    1930         )
#
# ~/anaconda3/envs/cefe/lib/python3.8/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     272
#     273             elif isinstance(data, np.ndarray):
# --> 274                 if len(data.dtype):
#     275                     # GH#13296 we are dealing with a compound dtype, which
#     276                     #  should be treated as 2D
#
# KeyboardInterrupt:

# %%
#plot the mean reaction per gabor filter
i=1
splitted_by_dir = merge_data.groupby([COL_DIRECTORY])
for category, split_data in splitted_by_dir:
    mean_data = split_data.groupby([COL_GABOR_ANGLES, COL_GABOR_FREQ]).agg({COL_GABOR_VALUES:np.mean})
    mean_data.reset_index(level=(0,1), inplace=True)
    map = mean_data.pivot(COL_GABOR_FREQ, COL_GABOR_ANGLES, COL_GABOR_VALUES)

    ax = plt.subplot(1,len(splitted_by_dir),i)
    ax.set_title(category)
    sns.heatmap(ax=ax, data=map, cbar=True, square=True)
    i+=1
    plt.show()

#plot the gabor filters
frequencies = merge_data[COL_GABOR_FREQ].unique()
angles = merge_data[COL_GABOR_ANGLES].unique()
f, axs = plt.subplots(len(frequencies), len(angles), squeeze=False)
for f, freq in enumerate(frequencies):
    for a, angle in enumerate(angles):
        gk = gabor_kernel(frequency=freq, theta=np.radians(angle))
        axs[f,a].imshow(gk.real)
        axs[f,a].set_title("frequency:{}, angle:{}".format(freq, angle))

plt.show()

# %%
for params, values in lbp_data.groupby(["points_LBP","radius_LBP"]):
    print(params)
    sns.relplot(data=values, x="value_LBP", y="count_LBP_value", hue="type")
    plt.show()
# Out:
# (8.0, 2.0)
# (16.0, 4.0)

# %% [markdown]
# # STATISTICAL MOMENTS

# %%
stat_path = "../../Results/NST_metrics/statistical_metrics.csv"
stat_data = pd.read_csv(stat_path, index_col=0)
stat_data = stat_data.merge(img_list, on="Image_path")
stat_data.head(3)
# Out:
#    normalization  standardization image_type channel_image  image_resize_x  \
# 0          False            False     DARTER          GRAY             NaN
# 1          False            False     DARTER          GRAY             NaN
# 2          False            False     DARTER          GRAY             NaN
#
#    image_resize_y                                         Image_path  \
# 0             NaN  /home/durrmeyer/Images/StyleTransferImages/HAB...
# 1             NaN  /home/durrmeyer/Images/StyleTransferImages/HAB...
# 2             NaN  /home/durrmeyer/Images/StyleTransferImages/HAB...
#
#     mean_stat   std_stat  skewness_stat  ...   habitat  color_control  \
# 0  751.839294  46.554649       0.988085  ...    PLANTS            NaN
# 1  759.116028  46.728863      -0.084126  ...  DETRITUS            NaN
# 2  754.493286  37.907387       0.841687  ...      SAND            NaN
#
#    tv_loss layers  sex fish_n species img_width img_height image_extension
# 0      NaN    NaN  NaN    NaN     NaN      3000       1000            .jpg
# 1      NaN    NaN  NaN    NaN     NaN      3000       1000            .jpg
# 2      NaN    NaN  NaN    NaN     NaN      3000       1000            .jpg
#
# [3 rows x 26 columns]

# %%
sns.relplot(data=stat_data, x="type", y="mean_stat")
plt.show()
sns.relplot(data=stat_data, x="type", y="std_stat")
plt.show()
sns.relplot(data=stat_data, x="type", y="skewness_stat")
plt.show()
sns.relplot(data=stat_data, x="type", y="kurtosis_stat")
plt.show()
sns.relplot(data=stat_data, x="type", y="entropy_stat")
plt.show()
sns.relplot(data=stat_data, x="type", y="gini_coefficient")
plt.show()

# %% [markdown]
# # COLOR RATIO

# %%
ratio_path = "../../Results/NST_metrics/color_ratio.csv"
ratio_data = pd.read_csv(ratio_path, index_col=0)
ratio_data = ratio_data.merge(img_list, on="Image_path")
ratio_data.head()
# Out:
#    normalization  standardization image_type channel_image  image_resize_x  \
# 0          False            False     DARTER           ALL             NaN
# 1          False            False     DARTER           ALL             NaN
# 2          False            False     DARTER           ALL             NaN
# 3          False            False     DARTER           ALL             NaN
# 4          False            False     DARTER           ALL             NaN
#
#    image_resize_y                                         Image_path  \
# 0             NaN  /home/durrmeyer/Images/StyleTransferImages/HAB...
# 1             NaN  /home/durrmeyer/Images/StyleTransferImages/HAB...
# 2             NaN  /home/durrmeyer/Images/StyleTransferImages/HAB...
# 3             NaN  /home/durrmeyer/Images/StyleTransferImages/HAB...
# 4             NaN  /home/durrmeyer/Images/StyleTransferImages/HAB...
#
#    color_ratio                                           filename     type  \
# 0     0.857268  PLANTS_cropped_3000x1000_middle_tt_resized_div...  habitat
# 1     0.648518  DETRITUS_cropped_3000x1000_middle_tt_resized_d...  habitat
# 2     0.794018  SAND_Eolmstedi_cropped_3000x1000_middle_tt_res...  habitat
# 3     0.772390  GRAVEL_cropped_3000x1000_middle_tt_resized_div...  habitat
# 4     0.759810  BOULDERxSAND_Eolmstedi_cropped_3000x1000_middl...  habitat
#
#    ...       habitat color_control tv_loss layers  sex fish_n  species  \
# 0  ...        PLANTS           NaN     NaN    NaN  NaN    NaN      NaN
# 1  ...      DETRITUS           NaN     NaN    NaN  NaN    NaN      NaN
# 2  ...          SAND           NaN     NaN    NaN  NaN    NaN      NaN
# 3  ...        GRAVEL           NaN     NaN    NaN  NaN    NaN      NaN
# 4  ...  BOULDERxSAND           NaN     NaN    NaN  NaN    NaN      NaN
#
#   img_width  img_height  image_extension
# 0      3000        1000             .jpg
# 1      3000        1000             .jpg
# 2      3000        1000             .jpg
# 3      3000        1000             .jpg
# 4      3000        1000             .jpg
#
# [5 rows x 21 columns]

# %%
sns.relplot(data=ratio_data, x="type", y="color_ratio")
plt.show()

# %% [markdown]
# # FOURIER SLOPE

# %%
fft_path = "../../Results/NST_metrics/FFT_slopes.csv"
fft_data = pd.read_csv(fft_path, index_col=0)
fft_data = fft_data.merge(img_list, on="Image_path")
fft_data.head()
# Out:
#    normalization  standardization image_type channel_image  image_resize_x  \
# 0          False            False     DARTER          GRAY           512.0
# 1          False            False     DARTER          GRAY           512.0
# 2          False            False     DARTER          GRAY           512.0
# 3          False            False     DARTER          GRAY           512.0
# 4          False            False     DARTER          GRAY           512.0
#
#    image_resize_y                                         Image_path  \
# 0          1536.0  /home/durrmeyer/Images/StyleTransferImages/HAB...
# 1          1536.0  /home/durrmeyer/Images/StyleTransferImages/HAB...
# 2          1536.0  /home/durrmeyer/Images/StyleTransferImages/HAB...
# 3          1536.0  /home/durrmeyer/Images/StyleTransferImages/HAB...
# 4          1536.0  /home/durrmeyer/Images/StyleTransferImages/HAB...
#
#    sample_idx_F  slope_sample_F  window_size_F  ...  habitat  color_control  \
# 0           0.0       -3.392233          512.0  ...   PLANTS            NaN
# 1           1.0       -4.266422          512.0  ...   PLANTS            NaN
# 2           2.0       -4.508030          512.0  ...   PLANTS            NaN
# 3           3.0       -4.200353          512.0  ...   PLANTS            NaN
# 4           4.0       -4.145240          512.0  ...   PLANTS            NaN
#
#   tv_loss layers  sex fish_n species img_width img_height image_extension
# 0     NaN    NaN  NaN    NaN     NaN      3000       1000            .jpg
# 1     NaN    NaN  NaN    NaN     NaN      3000       1000            .jpg
# 2     NaN    NaN  NaN    NaN     NaN      3000       1000            .jpg
# 3     NaN    NaN  NaN    NaN     NaN      3000       1000            .jpg
# 4     NaN    NaN  NaN    NaN     NaN      3000       1000            .jpg
#
# [5 rows x 25 columns]

# %%
sns.relplot(data=fft_data, x="type", y="slope_sample_F")
plt.show()

# %% [markdown]
# # GABOR

# %%
gabor_path = "../../Results/NST_metrics/gabor.csv"
gabor_data = pd.read_csv(gabor_path, index_col=0)
gabor_data = gabor_data.merge(img_list, on="Image_path")
gabor_data.head()
# Out:
#    normalization  standardization image_type channel_image  image_resize_x  \
# 0          False            False     DARTER          GRAY             NaN
# 1          False            False     DARTER          GRAY             NaN
# 2          False            False     DARTER          GRAY             NaN
# 3          False            False     DARTER          GRAY             NaN
# 4          False            False     DARTER          GRAY             NaN
#
#    image_resize_y                                         Image_path  \
# 0             NaN  /home/durrmeyer/Images/StyleTransferImages/HAB...
# 1             NaN  /home/durrmeyer/Images/StyleTransferImages/HAB...
# 2             NaN  /home/durrmeyer/Images/StyleTransferImages/HAB...
# 3             NaN  /home/durrmeyer/Images/StyleTransferImages/HAB...
# 4             NaN  /home/durrmeyer/Images/StyleTransferImages/HAB...
#
#    gabor_angles  gabor_frequencies  gabor_values  ... habitat color_control  \
# 0           0.0                0.2      1.078135  ...  PLANTS           NaN
# 1           0.0                0.4      1.506456  ...  PLANTS           NaN
# 2           0.0                0.8    510.619598  ...  PLANTS           NaN
# 3          45.0                0.2      0.627811  ...  PLANTS           NaN
# 4          45.0                0.4      1.107163  ...  PLANTS           NaN
#
#   tv_loss layers  sex fish_n species img_width  img_height image_extension
# 0     NaN    NaN  NaN    NaN     NaN      3000        1000            .jpg
# 1     NaN    NaN  NaN    NaN     NaN      3000        1000            .jpg
# 2     NaN    NaN  NaN    NaN     NaN      3000        1000            .jpg
# 3     NaN    NaN  NaN    NaN     NaN      3000        1000            .jpg
# 4     NaN    NaN  NaN    NaN     NaN      3000        1000            .jpg
#
# [5 rows x 23 columns]

# %%
sns.relplot(data=gabor_data, x="type", y="gabor_values", row="gabor_frequencies", col="gabor_angles")
plt.show()

# %% [markdown]
# # GLCM HARALICK DESCRIPTORS

# %%
haralick_path = "../../Results/NST_metrics/haralick.csv"
haralick_data = pd.read_csv(haralick_path, index_col=0)
haralick_data = haralick_data.merge(img_list, on="Image_path")
haralick_data.columns
# Out:
# Index(['normalization', 'standardization', 'image_type', 'channel_image',
#        'image_resize_x', 'image_resize_y', 'Image_path', 'GLCM_angle',
#        'GLCM_dist', 'GLCM_mean', 'GLCM_variance', 'GLCM_correlation',
#        'GLCM_contrast', 'GLCM_dissimilarity', 'GLCM_homogeneity', 'GLCM_ASM',
#        'GLCM_energy', 'GLCM_max_proba', 'GLCM_entropy', 'filename', 'type',
#        'folder', 'habitat', 'color_control', 'tv_loss', 'layers', 'sex',
#        'fish_n', 'species', 'img_width', 'img_height', 'image_extension'],
#       dtype='object')

# %%
sns.relplot(data=haralick_data, x="type", y="GLCM_entropy", row="GLCM_angle", col="GLCM_dist")
plt.show()
sns.relplot(data=haralick_data, x="type", y="GLCM_max_proba", row="GLCM_angle", col="GLCM_dist")
plt.show()
sns.relplot(data=haralick_data, x="type", y="GLCM_energy", row="GLCM_angle", col="GLCM_dist")
plt.show()
sns.relplot(data=haralick_data, x="type", y="GLCM_ASM", row="GLCM_angle", col="GLCM_dist")
plt.show()
sns.relplot(data=haralick_data, x="type", y="GLCM_homogeneity", row="GLCM_angle", col="GLCM_dist")
plt.show()
sns.relplot(data=haralick_data, x="type", y="GLCM_dissimilarity", row="GLCM_angle", col="GLCM_dist")
plt.show()
sns.relplot(data=haralick_data, x="type", y="GLCM_contrast", row="GLCM_angle", col="GLCM_dist")
plt.show()
sns.relplot(data=haralick_data, x="type", y="GLCM_correlation", row="GLCM_angle", col="GLCM_dist")
plt.show()
sns.relplot(data=haralick_data, x="type", y="GLCM_variance", row="GLCM_angle", col="GLCM_dist")
plt.show()
sns.relplot(data=haralick_data, x="type", y="GLCM_mean", row="GLCM_angle", col="GLCM_dist")
plt.show()

# %% [markdown]
# # DEEP FEATURES

# %%
df_path = "../../Results/NST_metrics/deep_features.csv"
df_data = pd.read_csv(df_path, index_col=0)
df_data = df_data.merge(img_list, on="Image_path")
df_data.columns
# Out:
# Index(['normalization', 'standardization', 'image_type', 'channel_image',
#        'image_resize_x', 'image_resize_y', 'Image_path',
#        'model_name_deep_features', 'gini_deep_features', 'layer_deep_feature',
#        'deep_feature_entropy', 'deep_feature_kurtosis', 'filename', 'type',
#        'folder', 'habitat', 'color_control', 'tv_loss', 'layers', 'sex',
#        'fish_n', 'species', 'img_width', 'img_height', 'image_extension'],
#       dtype='object')

# %%
sns.relplot(data=df_data, x="layer_deep_feature", y="gini_deep_features", hue="type", col="model_name_deep_features")
plt.show()
sns.relplot(data=df_data, x="layer_deep_feature", y="deep_feature_entropy", hue="type", col="model_name_deep_features")
plt.show()
sns.relplot(data=df_data, x="layer_deep_feature", y="deep_feature_kurtosis", hue="type", col="model_name_deep_features")
plt.show()
